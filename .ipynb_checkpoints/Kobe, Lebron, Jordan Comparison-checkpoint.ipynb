# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Seasons_Stats.csv')

# %%
df.drop(['Unnamed: 0', 'Age', 'Pos'] , axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Year', 'Player', 'Tm', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'blanl',
#        'OWS', 'DWS', 'WS', 'WS/48', 'blank2', 'OBPM', 'DBPM', 'BPM', 'VORP',
#        'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%',
#        'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV',
#        'PF', 'PTS'],
#       dtype='object')

# %%
mj_data = df.loc[df["Player"]=="Michael Jordan*"]
lb_data = df.loc[df["Player"]=="LeBron James"]
kb_data = df.loc[df["Player"]=="Kobe Bryant"]

# %%
mj_data2 = mj_data.loc[mj_data["G"]>60]
lb_data2 = lb_data.loc[lb_data["G"]>60]
kb_data2 = kb_data.loc[kb_data["G"]>60]

# %%
lb_describe = lb_data2[["TS%","FG%","3P%","2P%","FT%","PTS"]].describe()
kb_describe = kb_data2[["TS%","FG%","3P%","2P%","FT%","PTS"]].describe()
mj_describe = mj_data2[["TS%","FG%","3P%","2P%","FT%","PTS"]].describe()

# %%
lb_describe_aux = lb_data2[["ORB","DRB","TRB","AST","STL","BLK","TOV"]].describe()
kb_describe_aux = kb_data2[["ORB","DRB","TRB","AST","STL","BLK","TOV"]].describe()
mj_describe_aux = mj_data2[["ORB","DRB","TRB","AST","STL","BLK","TOV"]].describe()

# %%
sns.regplot(x="Year", y="3P%", data=lb_data2)
#sns.regplot(x="Year", y="3P%", data=kb_data2)
#sns.regplot(x="Year", y="3P%", data=mj_data2)

# %%
sns.regplot(x="Year", y="3P%", data=kb_data2)

# %%
sns.regplot(x="Year", y="3P%", data=mj_data2)
